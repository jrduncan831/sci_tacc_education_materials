# %% [markdown]
# <!-- ![](https://www.python.org/static/img/python-logo.png) -->
#
# # Introduction to Python
#
# In this notebook, we will demo the basic functionality of Python programming language.
#
#
# ## Why Python?
#
# Python has become one of the most popular languages, particularly in the data and computational science.  Below is an image from [Stackoverflow](https://insights.stackoverflow.com/trends?tags=java%2Cc%2Cc%2B%2B%2Cpython%2Cc%23%2Cvb.net%2Cjavascript%2Cassembly%2Cphp%2Cperl%2Cruby%2Cswift%2Cr%2Cobjective-c).
#
# <!-- <img src='img/stackoverflow_trends.png' width=600 /> -->
#
# ![](img/stackoverflow_trends_new.png)
#
# Here are some reason for pythons popularity:
#
# 1. Easy (easier than some other programming languages) to learn and use
# 2. Supports various programming paradigms (OOP, functional, procedural)
# 3. Most of Python's utility comes from extensive collection of libraries/modules - ecosystem.
# 4. Many of the most powerful AI and ML environments are accessed through python intefaces
#
# ## Importing modules
#
# Modules are code environments written to be accessed from within python.  Because there are so many different names and versions, you need to tell python which modules you will be using.  Often you will also need to install these modules, but for today, we have built an environment with them ready to use.

# %%
# Importing a module 
import numpy

# %%
# accessing a modules parameters
print(numpy.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ## Comments
#
# Comments are notes from past self to future self about what you are doing

# %%
# This is a single line comment

# %%
"""
This is a
multiline comment
This code will do nothing and has no variables 
or units to keep track of
"""
print()

# %% [markdown]
# ## Print Statements

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Python Data Types
#
# ## Basic Variable Types
#
# The basic data types in python are
#
# - integers
# - floats
# - strings
# - booleans
# - complex
#
# Python data types are dynamically inferred. Python distinguishes between integers and floats by whether the number contains a decimal place.

# %%
# Integer
apple_count = 10
# Float
apple_weight = 10.
# String
apple_name = "fuji"
# Boolean
is_an_apple = True

print(type(apple_count),type(apple_weight),type(apple_name),type(is_an_apple))

print("Is " + apple_name + " an apple? " + str(is_an_apple))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# Is fuji an apple? True

# %%
# Two ways to create comlex numbers

# The first way - using comlex function 
complex_number_1 = complex(4, 9)
print(complex_number_1)
print(type(complex_number_1))

# The second way - using typical complex notation
complex_number_2 = 3 + 5j
print(complex_number_2)
print(type(complex_number_2))
# Out:
# (4+9j)
# <class 'complex'>
# (3+5j)
# <class 'complex'>

# %% [markdown]
# ## Collections: List, Tuple, Dictionary
#
# Python and most modern languages follow the convention that arrays and lists of things start with an index of 0 and go to the last element being the array lenght minus one.  This is how computers think.  It does take some time getting used to.
#
# ### List
#
# A list is a collection of objects (int, floats, string, any other python object):
# - ordered - items stay in the same indexed position
# - changeable - can be changed after it is defined
#
# List are denoted with square brackets, i.e. [ and ]

# %%
numbers = [ "one", 2, 3. ]
print(numbers)
# Out:
# ['one', 2, 3.0]

# %% [markdown]
# List elements are indexed starting at zero.  You can access elements as follows:

# %%
numbers[2]
# Out:
# 3.0

# %% [markdown]
# Lists are changeable, so we can do things like append a new value to the end of a list.  Note each item has its own type

# %%
numbers.append("four")
numbers[2] = 5

print(numbers)
print(type(numbers[0]),type(numbers[1]),type(numbers[2]),type(numbers[3]))
# Out:
# ['one', 2, 5, 'four']
# <class 'str'> <class 'int'> <class 'int'> <class 'str'>

# %% [markdown]
# We can also compute the length of a list:

# %%
print(len(numbers))
# Out:
# 4

# %% [markdown]
# ### Tuple
#
# Tuples are similar to list, but they are immutable.  That is, tuples are
# - ordered
# - unchangable
#
# Typles are denoted with round brackets, i.e. ( and )

# %%
# Tuple
my_constants = (3.14, "taxes", 42)

# %%
# Tuple : access element
my_constants[1]
# Out:
# 'taxes'

# %%
# Get length of tuple
len(my_constants)
# Out:
# 3

# %%
# Tuple : no append method i.e immutable so you cannot add to the tuple
my_constants.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Tuple : no append method i.e immutable so you cannot add to the tuple
# ----> 2 my_constants.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# Nor can you change a value after it is defined

my_constants[1]="e"

# %% [markdown]
# ### Dictionary
#
# Dictionaries store data as key:value pairs.  They are commonly used as a simple way to structure data.  You can access elements in a dictionary via the key.  They are initilized with the currly brackets { and }, with the key and value separated by a colon : and each element in the dictionary separated by a comma

# %%
# Dictionary {Key:Value, Key:Value....}
shopping_list = {"carrots":1.5, "bag of rice":2, "coffee":"espresso bag"}

# %%
# Dictionary : access element by key
print(shopping_list["coffee"])
# Out:
# espresso bag

# %%
# Add new element
shopping_list["sugar"]="1 lb"
print(shopping_list)

# Get length of dictionary
print(len(shopping_list))
# Out:
# {'carrots': 1.5, 'bag of rice': 2, 'coffee': 'espresso bag', 'sugar': '1 lb'}
# 4

# %%
# Values can be other structures 

shopping_list["mixed_nuts"]={"weight": 8, "unit": "oz"}
# Get length of dictionary
print(len(shopping_list))
print(shopping_list)
# Out:
# 5
# {'carrots': 1.5, 'bag of rice': 2, 'coffee': 'espresso bag', 'sugar': '1 lb', 'mixed_nuts': {'weight': 8, 'unit': 'oz'}}

# %%
# thats hard to read so lets use pretty print which is called pprint in the module pprint
# note this is horrible abbrivations and dupications but its not going to change

from pprint import pprint
pprint(shopping_list)
# Out:
# {'bag of rice': 2,
#  'carrots': 1.5,
#  'coffee': 'espresso bag',
#  'mixed_nuts': {'unit': 'oz', 'weight': 8},
#  'sugar': '1 lb'}

# %%
# You can also go through the keys to see if an element is in there

print(shopping_list.keys())
print("flour" in shopping_list.keys())
# Out:
# dict_keys(['carrots', 'bag of rice', 'coffee', 'sugar', 'mixed_nuts'])
# False

# %% [markdown]
# ## Final Comments on Python Data Types
#
# Everything in python is an object.  That means that all data types have there on methods that manipulate the object.  For example, append() is a method for the list data type.
#
# This means for each data element, the interpreter has to see what types are involved and make the right call for those two elements.  This is why the following does not work as it trys to do the add opperand on a string and an integer which doesn't work

# %%
name = "Ada Lovelace"
age = 32
print(name + " " + age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 name = "Ada Lovelace"
#       2 age = 32
# ----> 3 print(name + " " + age)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Control Flow
#
# Before we demo python's control flow syntax, lets point out a few things about Python's syntax:
#
# - Indentations matter in python; they specify code block boundaries
#
# We will use the following list in the control flow demos:

# %%
numbers = [1,2,3,4]

# %% [markdown]
# Before we demo the if/else syntax, below I highlight additional syntax included in this demo

# %%
print(3==0) # boolean operater == asks if elements are the same
# Out:
# False

# %%
print(4%2)  # arithmetic: % is the remainder
# Out:
# 0

# %% [markdown]
# ## if/else statements
#
# In the demo below, I determine if there are no elements in the list or if there are even or odd number of elements.

# %%
if len(numbers)==0:  # boolean operater == asks if elements are the same 
    print("empty list")
elif len(numbers)%2==0:
    print("Even number of elements")
    print("!")
else:
    print("Odd number of elements")
# Out:
# Even number of elements
# !

# %% [markdown]
# ## For loop : Print even index elements of the list
#
# In the demo below I print the even index elements of the list

# %%
for element in numbers:
    if numbers.index(element)%2==0:
        print(element)
    else:
        # pass does nothing
        pass
    print('test')
# Out:
# 1
# test
# test
# 3
# test
# test

# %% [markdown]
# ## While loop : Search for things in list

# %%
# Example 1
i = 0
while i < 4:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3

# %%
# Example 2
i = 0
while i < 5:
    i+=1
    if i % 2 == 0:
        continue
    elif i == 3:
        break
    print(i)
# Out:
# 1

# %% [markdown]
# ## Defining Functions
#
# Below we define a function to search a list for an element and return its index if found and -1 if not found.  Returning a negative number from a list search is commonly used to say it was not found

# %%
def print_name(name):
    print('My name is {}'.format(name))
    
print_name('bob')
# Out:
# My name is bob

# %%
# so we have a list of our family

family_members = ["Mom", "Dad", "Kenny", "Julia"]

# %%
def search_list_for_element(element, search_list):
    index=0
    while index < len(search_list):
        if search_list[index] == element:
            break
        else:
            index+=1
            continue
    #If index is less than length, element is found
    if index < len(search_list):
        return index
    else:
        return -1

# %%
print(family_members)
# Out:
# ['Mom', 'Dad', 'Kenny', 'Julia']

# %%
#search_list_for_element('z', example_list)
search_list_for_element('Dad', family_members)
# Out:
# 1

# %% [markdown]
# <a id='matplotlib'></a>
#
# # Matplotlib
#
# Matplotlib has two styles interfaces when using the library:
#
# - explicit "axes" interface
#    * gives user full control over the figure
#    * harder to use, but gives user more control
# - implicit "pyplot" interface
#    * matplotlib infers what user wants
#    * easier to use, but give user less control
#
# Read the [docs](https://matplotlib.org/devdocs/users/explain/api_interfaces.html) for more information
#
# ## pyplot interface

# %%
# For plots inline in notebook
# %matplotlib inline 

# Import matplotlib
import matplotlib.pyplot as plt

# we will also need numpy
import numpy as np

# %% [markdown]
# In the demo below we create several plots with the same data.  Note that in the various demos we just change a few parameters to change things like the color of the graph, scatter versus plot, etc.

# %%
# Setup X and Y values
x = np.linspace(0,25, 20)
y = np.sqrt(x)

# Create plot
plt.xlabel('This is X label')
plt.ylabel('This is Y label')
print(x)
print(y)
plt.plot(x,y);
# Out:
# [ 0.          1.31578947  2.63157895  3.94736842  5.26315789  6.57894737
#   7.89473684  9.21052632 10.52631579 11.84210526 13.15789474 14.47368421
#  15.78947368 17.10526316 18.42105263 19.73684211 21.05263158 22.36842105
#  23.68421053 25.        ]
# [0.         1.14707867 1.62221421 1.98679854 2.29415734 2.56494588
#  2.80975743 3.03488489 3.24442842 3.44123601 3.62738125 3.80442955
#  3.97359707 4.13585096 4.29197538 4.44261658 4.58831468 4.72952651
#  4.86664263 5.        ]

# %% [markdown]
# ## Axes interface
#
# In the demo below we will create two plots in one figure using the axes interface.  The two plots will show a sine and cosine wave

# %%
#get data for plot demo
x=np.arange(0,1,0.025)
y1=10*np.cos(2*np.pi*5*x)
y2=10*np.sin(2*np.pi*5*x)

# %%
figure, axes = plt.subplots(2,1)

# %% [markdown]
# Above we instantiated a fig and axs object used to control a figure. The diagram below highlights what these two objects control:
#
# ![](img/axes_matplotlib.png)
#
# `.tight_layout()` is an example of a fig method.

# %%
figure2, axes2 = plt.subplots(2,2)
figure2.tight_layout()

# %%
figure, axes = plt.subplots(2,1)
axes[0].plot(x,y1,'r-')
axes[1].plot(x,y2,'k--')
axes[1].set_xlabel('This is X label')
axes[0].set_ylabel('This is Y label 1')
axes[1].set_ylabel('This is Y label 2')
figure.tight_layout();

# %% [markdown]
# ## Datasets and Libraries exploration (numpy, pandas)
# In this section we will do a preliminary exploration of the different datasets we will use in the training

# %% [markdown]
# ### Galaxy10
# name:
# galaxy10
#
# description:
# the Sloan Digital Sky Survey (SDSS) is an ongoing astronomical imaging survey conducted by the Apache Point Observatory in Sunspot, New Mexico. This dataset collects roughly 15,000 telescope images associated with the SDSS, all of which were chosen for their high signal-to-noise ratio. Each image is centered about a single celestial object (e.g., a star, a galaxy, a quasar, etc.) and takes the form of a 256 px x 256 px tensor in RGB space. Note that each element of the RGB tuple corresponds to the intensity associated with a specific light frequency band.
#
# purpose:
# we intend to use this data for a hands-on example of dimensionality reduction (PCA) and k-means/GMM clustering.
#
# original data source:
# https://github.com/MultimodalUniverse/MultimodalUniverse
# (see the Galaxy10DeCaLS submodule)
#
#
# ==========
#
# The Galaxy10 h5 file contains the following keys:
#
#     'images' -  the collection of all 17,000 SDSS photometric images. Each image consists of a 256 x 256 x 3 tensor in RGB space.
#
#     'ans' - the class label for each image. This field takes a value in range(0,10). The value of each image is based upon a manual classification of the celestial object within the frame. This field is to be used as the ground truth for supervised learning tasks.
#
#
# ==========

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import h5py

# %%
dataset_path = '/scratch1/10386/lsmith9003/share/tutorialDatagalaxy10/Galaxy10_DECals.h5'
dataset_path = ''

# %%
with h5py.File(dataset_path,'r') as File:
    X = np.array(File['images'])
    Y = np.array(File['ans'])

# %%
X[1].shape

# %%
Y.shape

# %% [markdown]
# ## class distribution
#
# plot distribution across all classes

# %%
plt.hist(Y, density=True)

# %% [markdown]
# ### example from each class
#
# Galaxy10 dataset (17736 images)
#
# Class 0 (1081 images): Disturbed Galaxies <br/>
# Class 1 (1853 images): Merging Galaxies <br/>
# Class 2 (2645 images): Round Smooth Galaxies <br/>
# Class 3 (2027 images): In-between Round Smooth Galaxies <br/>
# Class 4 ( 334 images): Cigar Shaped Smooth Galaxies <br/>
# Class 5 (2043 images): Barred Spiral Galaxies <br/>
# Class 6 (1829 images): Unbarred Tight Spiral Galaxies <br/>
# Class 7 (2628 images): Unbarred Loose Spiral Galaxies <br/>
# Class 8 (1423 images): Edge-on Galaxies without Bulge <br/>
# Class 9 (1873 images): Edge-on Galaxies with Bulge

# %%
figure, axes = plt.subplots(4,3)
for row in range(4):
    for col in range(3):
        if(row>2 and col>0):
            break;
        axes[row,col].imshow(X[np.where(Y==row*3+col)[0][0]])
figure.tight_layout()

# %%
image = X[np.where(Y==2)[0][0]]

# %%
plt.imshow(image)
plt.colorbar()

# %%
plt.hist(image.ravel(),bins=range(256));

# %%
figure, axes = plt.subplots(1,3)
axes[0].imshow(image[:,:,0])
axes[1].imshow(image[:,:,1])
ax = axes[2].imshow(image[:,:,2])
axes[0].set_title("R")
axes[1].set_title("G")
axes[2].set_title("B");
cax=figure.add_axes([0.95,0.1,0.01,0.8])
figure.colorbar(ax, cax=cax)
